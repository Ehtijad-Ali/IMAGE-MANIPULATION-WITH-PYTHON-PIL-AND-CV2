# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/lenna.png -O lenna.png
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/baboon.png -O baboon.png
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/barbara.png -O barbara.png
# Out:
# --2024-10-07 16:28:23--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/lenna.png
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 473831 (463K) [image/png]
# Saving to: ‘lenna.png’
#
# lenna.png           100%[===================>] 462.73K  2.62MB/s    in 0.2s
#
# 2024-10-07 16:28:23 (2.62 MB/s) - ‘lenna.png’ saved [473831/473831]
#
# --2024-10-07 16:28:23--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/baboon.png
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
img = np.array(Image.open('/content/pexels-jonathanborba-26337019.jpg'))
plt.figure(figsize=(5,5))
plt.imshow(img)
plt.show()

# %%
# here we are copying image
A = img

# %%
# We use the id function to find a variable's memory address; we see the objects in the memory space which the variables A
# and **img** point to are the same.
id(A) == id(img)
# Out:
# True

# %%
# if we apply method copy(), their memory addresses will be different.
B = img.copy()
id(B)==id(img)
# Out:
# False

# %%
img[:,:,] = 0

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(img)
plt.title("A Man")
plt.subplot(122)
plt.imshow(A)
plt.title("A Women")
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(img)
plt.title("A Man")
plt.subplot(122)
plt.imshow(B)
plt.title("array B")
plt.show()

# %%
# Flipping images
img2 = Image.open('/content/pexels-jonathanborba-26337019.jpg')
plt.figure(figsize=(10,6))
plt.imshow(img2)
plt.show()

# %%
array = np.array(img2)
width, height, C = array.shape
print('width', width ,'height and Channel', height, C)
# Out:
# width 3269 height and Channel 4903 3

# %%
array_flip = np.zeros((width, height, C), dtype=np.uint8)

# %%
for i,row in enumerate(array):
    array_flip[width - 1 - i, :, :] = row

# %%
array_flip
# Out:
# array([[[111, 111, 109],
#         [108, 108, 106],
#         [108, 108, 106],
#         ...,
#         [142, 143, 145],
#         [142, 143, 145],
#         [142, 143, 145]],
#
#        [[111, 111, 109],
#         [108, 108, 106],
#         [109, 109, 107],
#         ...,
#         [143, 144, 146],
#         [143, 144, 146],
#         [143, 144, 146]],
#
#        [[111, 111, 109],
#         [109, 109, 107],
#         [110, 110, 108],
#         ...,
#         [144, 145, 147],
#         [145, 146, 148],
#         [145, 146, 148]],
#
#        ...,
#
#        [[138, 139, 141],
#         [139, 140, 142],
#         [141, 142, 144],
#         ...,
#         [125, 125, 125],
#         [126, 126, 126],
#         [127, 127, 127]],
#
#        [[133, 134, 136],
#         [137, 138, 140],
#         [140, 141, 143],
#         ...,
#         [124, 124, 124],
#         [125, 125, 125],
#         [126, 126, 126]],
#
#        [[128, 129, 131],
#         [132, 133, 135],
#         [137, 138, 140],
# ...

# %%
from PIL import ImageOps
# Here we will rotate imge vertically vertically. The flip() method of ImageOps module flips the image.
# The mirror() method will mirror the image:

im_flip = ImageOps.flip(img2)
plt.figure(figsize=(10,5))
plt.imshow(im_flip)
plt.show()

# %%
im_mirror = ImageOps.mirror(img2)
plt.figure(figsize=(10,5))
plt.imshow(im_mirror)
plt.show()

# %%
im_flip = img2.transpose(1)
plt.imshow(im_flip)
plt.show()

# %%
flip = {"FLIP_LEFT_RIGHT": Image.FLIP_LEFT_RIGHT,
        "FLIP_TOP_BOTTOM": Image.FLIP_TOP_BOTTOM,
        "ROTATE_90": Image.ROTATE_90,
        "ROTATE_180": Image.ROTATE_180,
        "ROTATE_270": Image.ROTATE_270,
        "TRANSPOSE": Image.TRANSPOSE,
        "TRANSVERSE": Image.TRANSVERSE}

# %%
flip["FLIP_LEFT_RIGHT"]
# Out:
# 0

# %%
for key, values in flip.items():
    plt.figure(figsize=(5,5))
    plt.subplot(1,2,1)
    plt.imshow(img2)
    plt.title("orignal")
    plt.subplot(1,2,2)
    plt.imshow(img2.transpose(values))
    plt.title(key)
    plt.show()

# %%
#Let start with a vertical crop: the variable upper is the index of the first row that we would like to include in the image,
#lower variable is the index of the last row we would like to include. We then perform array slicing to obtain the new image.
upper = 60
lower = 1500

crop_top = array[upper: lower,:,:]
plt.figure(figsize=(5,5))
plt.imshow(crop_top)
plt.show()

# %%
left = 100
right = 3500
crop_horizontal = crop_top[: ,left:right,:]
plt.figure(figsize=(5,5))
plt.imshow(crop_horizontal)
plt.show()

# %%
#You can crop the PIL image using the crop() method, using the parameters from above Set the cropping area with
#box=(left, upper, right, lower).
image = Image.open("/content/pexels-jonathanborba-26337019.jpg")
image = image.convert("RGB")
crop_image = image.crop((left, upper, right, lower))
plt.figure(figsize=(5,5))
plt.imshow(crop_image)
plt.show()

# %%
import cv2

# Load an image
image = cv2.imread('/content/pexels-jonathanborba-26337019.jpg')

# Display the image
plt.imshow(image)



# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display the grayscale image
plt.imshow(gray_image)


# Save the grayscale image
cv2.imwrite('gray_image.jpg', gray_image)

# Apply edge detection
edges = cv2.Canny(gray_image, 100, 200)

# Display the edges
plt.imshow(edges)
